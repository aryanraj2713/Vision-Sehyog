# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13639, done.
# remote: Counting objects: 100% (441/441), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 13639 (delta 321), reused 403 (delta 293), pack-reused 13198
# Receiving objects: 100% (13639/13639), 13.27 MiB | 837.00 KiB/s, done.
# Resolving deltas: 100% (9380/9380), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt

# %%
import torch

from IPython.display import Image,clear_output
print("Setup Complete")
# Out:
# Setup Complete

# %%
# !python3 train.py --img k --batch 2 --epochs 60 --data custom.yaml --weights yolov5x.pt --nosave --cache
# Out:
# 696.18s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# train: weights=yolov5x.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=4, imgsz=640, rect=False, resume=False, nosave=True, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# fatal: cannot change to '/home/samantha/Desktop/Aryan': No such file or directory
# YOLOv5 🚀 2022-10-8 Python-3.10.6 torch-1.12.1+cu102 CUDA:0 (NVIDIA TITAN X (Pascal), 12193MiB)
#
# ...

# %%
# !python3 detect.py --weights runs/train/exp2/weights/last.pt --img 640 --conf 0.25 --source ../videoplayback.mp4
